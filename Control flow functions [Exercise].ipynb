# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Control flow functions

# %% [markdown]
# In this exercise, we'll use control flow functions to break down a complex problem into its fundamental components.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn to:
# - Use the `IIF` control function to check for a certain condition and return a value for each scenario.
# - Use the `CASE` statement to categorise data in an existing column.

# %% [markdown]
# First, let's load our sample database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
# Load the Northwind database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///Northwind.db
# Out:
# 'Connected: @Northwind.db'

# %% [markdown]
# Here is a view of all of our tables in the database:
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png"  style="width:70%";/>
# <br>
# <br>
#     <em>Figure 1: Northwind database ERD</em>
# </div>

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Categorise employees based on salaries
#
# Using the `Employees` table in the Northwind database, write a SQL query that returns a list of all employees along with a column `HighSalary` that shows 'Yes' if the employee's salary is above \$50,000 and 'No' otherwise.

# %%
# %%sql
# SELECT
#     LastName,
#     FirstName,
#     Salary,
#     IF(Salary > 50000, "Yes", "No") AS HighSalary
# FROM
#     employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Davolio', 'Nancy', 2954.55, 'No'),
#  ('Fuller', 'Andrew', 2254.49, 'No'),
#  ('Leverling', 'Janet', 3119.15, 'No'),
#  ('Peacock', 'Margaret', 1861.08, 'No'),
#  ('Buchanan', 'Steven', 1744.21, 'No'),
#  ('Suyama', 'Michael', 2004.07, 'No'),
#  ('King', 'Robert', 1991.55, 'No'),
#  ('Callahan', 'Laura', 2100.5, 'No'),
#  ('Dodsworth', 'Anne', 2333.33, 'No')]

# %% [markdown]
# ### 2. Categorise orders based on quantity
#
# Based on the `OrderDetails` table, write a SQL query that categorises orders into 'Small', 'Medium', or 'Large' based on the order quantity: Small (less than 20), Medium (between 20 and 100), and Large (more than 100).

# %%
# %%sql
# SELECT
#     OrderID,
#     CASE
#         WHEN Quantity < 20 THEN "Small"
#         WHEN Quantity BETWEEN 20 AND 100 THEN "Medium"
#         ELSE "Large"
#     END As OrderSize
# FROM
#     OrderDetails;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(10248, 'Small'),
#  (10248, 'Small'),
#  (10248, 'Small'),
#  (10249, 'Small'),
#  (10249, 'Medium'),
#  (10250, 'Small'),
#  (10250, 'Medium'),
#  (10250, 'Small'),
#  (10251, 'Small'),
#  (10251, 'Small'),
#  (10251, 'Medium'),
#  (10252, 'Medium'),
#  (10252, 'Medium'),
#  (10252, 'Medium'),
#  (10253, 'Medium'),
#  (10253, 'Medium'),
#  (10253, 'Medium'),
#  (10254, 'Small'),
#  (10254, 'Medium'),
#  (10254, 'Medium'),
#  (10255, 'Medium'),
#  (10255, 'Medium'),
#  (10255, 'Medium'),
#  (10255, 'Medium'),
#  (10256, 'Small'),
#  (10256, 'Small'),
#  (10257, 'Medium'),
#  (10257, 'Small'),
#  (10257, 'Small'),
#  (10258, 'Medium'),
#  (10258, 'Medium'),
#  (10258, 'Small'),
#  (10259, 'Small'),
#  (10259, 'Small'),
#  (10260, 'Small'),
#  (10260, 'Medium'),
#  (10260, 'Small'),
#  (10260, 'Medium'),
#  (10261, 'Medium'),
#  (10261, 'Medium'),
#  (10262, 'Small'),
#  (10262, 'Small'),
#  (10262, 'Small'),
#  (10263, 'Medium'),
#  (10263, 'Medium'),
#  (10263, 'Medium'),
#  (10263, 'Medium'),
#  (10264, 'Medium'),
#  (10264, 'Medium'),
#  (10265, 'Medium'),
#  (10265, 'Medium'),
#  (10266, 'Small'),
#  (10267, 'Medium'),
#  (10267, 'Medium'),
#  (10267, 'Small'),
#  (10268, 'Small'),
#  (10268, 'Small'),
#  (10269, 'Medium'),
#  (10269, 'Medium'),
#  (10270, 'Medium'),
#  (10270, 'Medium'),
#  (10271, 'Medium'),
#  (10272, 'Small'),
#  (10272, 'Medium'),
#  (10272, 'Medium'),
#  (10273, 'Medium'),
#  (10273, 'Small'),
#  (10273, 'Medium'),
#  (10273, 'Medium'),
#  (10273, 'Medium'),
#  (10274, 'Medium'),
#  (10274, 'Small'),
#  (10275, 'Small'),
#  (10275, 'Small'),
#  (10276, 'Small'),
#  (10276, 'Small'),
#  (10277, 'Medium'),
#  (10277, 'Small'),
#  (10278, 'Small'),
#  (10278, 'Small'),
#  (10278, 'Small'),
#  (10278, 'Medium'),
#  (10279, 'Small'),
#  (10280, 'Small'),
#  (10280, 'Medium'),
#  (10280, 'Medium'),
#  (10281, 'Small'),
#  (10281, 'Small'),
#  (10281, 'Small'),
#  (10282, 'Small'),
#  (10282, 'Small'),
#  (10283, 'Medium'),
#  (10283, 'Small'),
#  (10283, 'Medium'),
#  (10283, 'Small'),
#  (10284, 'Small'),
#  (10284, 'Medium'),
#  (10284, 'Medium'),
#  (10284, 'Small'),
#  (10285, 'Medium'),
#  (10285, 'Medium'),
#  (10285, 'Medium'),
#  (10286, 'Medium'),
#  (10286, 'Medium'),
#  (10287, 'Medium'),
#  (10287, 'Medium'),
#  (10287, 'Small'),
#  (10288, 'Small'),
#  (10288, 'Small'),
#  (10289, 'Medium'),
#  (10289, 'Small'),
#  (10290, 'Medium'),
#  (10290, 'Small'),
#  (10290, 'Small'),
#  (10290, 'Small'),
#  (10291, 'Medium'),
#  (10291, 'Medium'),
#  (10291, 'Small'),
#  (10292, 'Medium'),
#  (10293, 'Small'),
#  (10293, 'Small'),
#  (10293, 'Small'),
#  (10293, 'Small'),
#  (10294, 'Small'),
#  (10294, 'Small'),
#  (10294, 'Small'),
#  (10294, 'Medium'),
#  (10294, 'Small'),
#  (10295, 'Small'),
#  (10296, 'Small'),
#  (10296, 'Medium'),
#  (10296, 'Small'),
#  (10297, 'Medium'),
#  (10297, 'Medium'),
#  (10298, 'Medium'),
#  (10298, 'Medium'),
#  (10298, 'Medium'),
#  (10298, 'Small'),
#  (10299, 'Small'),
#  (10299, 'Medium'),
#  (10300, 'Medium'),
#  (10300, 'Medium'),
#  (10301, 'Small'),
#  (10301, 'Medium'),
#  (10302, 'Medium'),
#  (10302, 'Medium'),
#  (10302, 'Small'),
#  (10303, 'Medium'),
#  (10303, 'Medium'),
#  (10303, 'Small'),
#  (10304, 'Medium'),
#  (10304, 'Small'),
#  (10304, 'Small'),
#  (10305, 'Medium'),
#  (10305, 'Medium'),
#  (10305, 'Medium'),
#  (10306, 'Small'),
#  (10306, 'Small'),
#  (10350, 'Small'),
#  (10350, 'Small'),
#  (10351, 'Medium'),
#  (10351, 'Small'),
#  (10351, 'Medium'),
#  (10351, 'Small'),
#  (10352, 'Small'),
#  (10352, 'Medium'),
#  (10353, 'Small'),
#  (10353, 'Medium'),
#  (10354, 'Small'),
#  (10354, 'Small'),
#  (10355, 'Medium'),
#  (10355, 'Medium'),
#  (10356, 'Medium'),
#  (10356, 'Small'),
#  (10356, 'Medium'),
#  (10357, 'Medium'),
#  (10357, 'Small'),
#  (10357, 'Small'),
#  (10358, 'Small'),
#  (10358, 'Small'),
#  (10358, 'Medium'),
#  (10359, 'Medium'),
#  (10359, 'Medium'),
#  (10359, 'Medium'),
#  (10360, 'Medium'),
#  (10360, 'Medium'),
#  (10360, 'Small'),
#  (10360, 'Medium'),
#  (10360, 'Medium'),
#  (10361, 'Medium'),
#  (10361, 'Medium'),
#  (10362, 'Medium'),
#  (10362, 'Medium'),
#  (10362, 'Medium'),
#  (10363, 'Medium'),
#  (10363, 'Small'),
#  (10363, 'Small'),
#  (10364, 'Medium'),
#  (10364, 'Small'),
#  (10365, 'Medium'),
#  (10366, 'Small'),
#  (10366, 'Small'),
#  (10367, 'Medium'),
#  (10367, 'Small'),
#  (10367, 'Small'),
#  (10367, 'Small'),
#  (10368, 'Small'),
#  (10368, 'Small'),
#  (10368, 'Medium'),
#  (10368, 'Medium'),
#  (10369, 'Medium'),
#  (10369, 'Small'),
#  (10370, 'Small'),
#  (10370, 'Medium'),
#  (10370, 'Medium'),
#  (10371, 'Small'),
#  (10372, 'Small'),
#  (10372, 'Medium'),
#  (10372, 'Medium'),
#  (10372, 'Medium'),
#  (10373, 'Medium'),
#  (10373, 'Medium'),
#  (10374, 'Medium'),
#  (10374, 'Small'),
#  (10375, 'Small'),
#  (10375, 'Small'),
#  (10376, 'Medium'),
#  (10377, 'Medium'),
#  (10377, 'Medium'),
#  (10378, 'Small'),
#  (10379, 'Small'),
#  (10379, 'Small'),
#  (10379, 'Medium'),
#  (10380, 'Small'),
#  (10380, 'Medium'),
#  (10380, 'Small'),
#  (10380, 'Medium'),
#  (10381, 'Small'),
#  (10382, 'Medium'),
#  (10382, 'Small'),
#  (10382, 'Small'),
#  (10382, 'Medium'),
#  (10382, 'Medium'),
#  (10383, 'Medium'),
#  (10383, 'Small'),
#  (10383, 'Medium'),
#  (10384, 'Medium'),
#  (10384, 'Small'),
#  (10385, 'Small'),
#  (10385, 'Medium'),
#  (10385, 'Small'),
#  (10386, 'Small'),
#  (10386, 'Small'),
#  (10387, 'Small'),
#  (10387, 'Small'),
#  (10387, 'Small'),
#  (10387, 'Small'),
#  (10388, 'Small'),
#  (10388, 'Medium'),
#  (10388, 'Medium'),
#  (10389, 'Small'),
#  (10389, 'Small'),
#  (10389, 'Medium'),
#  (10389, 'Medium'),
#  (10390, 'Medium'),
#  (10390, 'Medium'),
#  (10390, 'Medium'),
#  (10390, 'Medium'),
#  (10391, 'Small'),
#  (10392, 'Medium'),
#  (10393, 'Medium'),
#  (10393, 'Medium'),
#  (10393, 'Small'),
#  (10393, 'Medium'),
#  (10393, 'Medium'),
#  (10394, 'Small'),
#  (10394, 'Small'),
#  (10395, 'Medium'),
#  (10395, 'Medium'),
#  (10395, 'Small'),
#  (10396, 'Medium'),
#  (10396, 'Medium'),
#  (10396, 'Medium'),
#  (10397, 'Small'),
#  (10397, 'Small'),
#  (10398, 'Medium'),
#  (10398, 'Large'),
#  (10399, 'Medium'),
#  (10399, 'Medium'),
#  (10399, 'Medium'),
#  (10399, 'Small'),
#  (10400, 'Medium'),
#  (10400, 'Medium'),
#  (10400, 'Medium'),
#  (10401, 'Small'),
#  (10401, 'Medium'),
#  (10401, 'Medium'),
#  (10401, 'Medium'),
#  (10402, 'Medium'),
#  (10402, 'Medium'),
#  (10403, 'Medium'),
#  (10403, 'Medium'),
#  (10404, 'Medium'),
#  (10404, 'Medium'),
#  (10404, 'Medium'),
#  (10405, 'Medium'),
#  (10406, 'Small'),
#  (10406, 'Medium'),
#  (10406, 'Medium'),
#  (10406, 'Small'),
#  (10406, 'Small'),
#  (10407, 'Medium'),
#  (10407, 'Small'),
#  (10407, 'Small'),
#  (10408, 'Small'),
#  (10408, 'Small'),
#  (10408, 'Medium'),
#  (10409, 'Small'),
#  (10409, 'Small'),
#  (10410, 'Medium'),
#  (10410, 'Small'),
#  (10411, 'Medium'),
#  (10411, 'Medium'),
#  (10411, 'Small'),
#  (10412, 'Medium'),
#  (10413, 'Medium'),
#  (10413, 'Medium'),
#  (10413, 'Small'),
#  (10414, 'Small'),
#  (10414, 'Medium'),
#  (10415, 'Small'),
#  (10415, 'Medium'),
#  (10416, 'Medium'),
#  (10416, 'Small'),
#  (10416, 'Medium'),
#  (10417, 'Medium'),
#  (10417, 'Small'),
#  (10417, 'Medium'),
#  (10417, 'Medium'),
#  (10418, 'Medium'),
#  (10418, 'Medium'),
#  (10418, 'Small'),
#  (10418, 'Small'),
#  (10419, 'Medium'),
#  (10419, 'Medium'),
#  (10420, 'Medium'),
#  (10420, 'Small'),
#  (10420, 'Small'),
#  (10420, 'Medium'),
#  (10421, 'Small'),
#  (10421, 'Medium'),
#  (10421, 'Small'),
#  (10421, 'Small'),
#  (10422, 'Small'),
#  (10423, 'Small'),
#  (10423, 'Medium'),
#  (10424, 'Medium'),
#  (10424, 'Medium'),
#  (10424, 'Medium'),
#  (10425, 'Small'),
#  (10425, 'Medium'),
#  (10426, 'Small'),
#  (10426, 'Small'),
#  (10427, 'Medium'),
#  (10428, 'Medium'),
#  (10429, 'Medium'),
#  (10429, 'Medium'),
#  (10430, 'Medium'),
#  (10430, 'Medium'),
#  (10430, 'Medium'),
#  (10430, 'Medium'),
#  (10431, 'Medium'),
#  (10431, 'Medium'),
#  (10431, 'Medium'),
#  (10432, 'Small'),
#  (10432, 'Medium'),
#  (10433, 'Medium'),
#  (10434, 'Small'),
#  (10434, 'Small'),
#  (10435, 'Small'),
#  (10435, 'Small'),
#  (10435, 'Small'),
#  (10436, 'Small'),
#  (10436, 'Medium'),
#  (10436, 'Medium'),
#  (10436, 'Medium'),
#  (10437, 'Small'),
#  (10438, 'Small'),
#  (10438, 'Medium'),
#  (10438, 'Small'),
#  (10439, 'Small'),
#  (10439, 'Small'),
#  (10439, 'Small'),
#  (10439, 'Medium'),
#  (10440, 'Medium'),
#  (10440, 'Medium'),
#  (10440, 'Medium'),
#  (10440, 'Medium'),
#  (10441, 'Medium'),
#  (10442, 'Medium'),
#  (10442, 'Medium'),
#  (10442, 'Medium'),
#  (10443, 'Small'),
#  (10443, 'Small'),
#  (10444, 'Small'),
#  (10444, 'Small'),
#  (10444, 'Small'),
#  (10444, 'Medium'),
#  (10445, 'Small'),
#  (10445, 'Small'),
#  (10446, 'Small'),
#  (10446, 'Medium'),
#  (10446, 'Small'),
#  (10446, 'Small'),
#  (10447, 'Medium'),
#  (10447, 'Medium'),
#  (10447, 'Small'),
#  (10448, 'Small'),
#  (10448, 'Medium'),
#  (10449, 'Small'),
#  (10449, 'Medium'),
#  (10449, 'Medium'),
#  (10450, 'Medium'),
#  (10450, 'Small'),
#  (10451, 'Large'),
#  (10451, 'Medium'),
#  (10451, 'Medium'),
#  (10451, 'Medium'),
#  (10452, 'Small'),
#  (10452, 'Medium'),
#  (10453, 'Small'),
#  (10453, 'Medium'),
#  (10454, 'Medium'),
#  (10454, 'Medium'),
#  (10454, 'Small'),
#  (10455, 'Medium'),
#  (10455, 'Medium'),
#  (10455, 'Medium'),
#  (10455, 'Medium'),
#  (10456, 'Medium'),
#  (10456, 'Medium'),
#  (10457, 'Medium'),
#  (10458, 'Medium'),
#  (10458, 'Medium'),
#  (10458, 'Medium'),
#  (10458, 'Small'),
#  (10458, 'Medium'),
#  (10459, 'Small'),
#  (10459, 'Medium'),
#  (10459, 'Medium'),
#  (10460, 'Medium'),
#  (10460, 'Small'),
#  (10461, 'Medium'),
#  (10461, 'Medium'),
#  (10461, 'Medium'),
#  (10462, 'Small'),
#  (10462, 'Medium'),
#  (10463, 'Medium'),
#  (10463, 'Medium'),
#  (10464, 'Small'),
#  (10464, 'Small'),
#  (10464, 'Medium'),
#  (10464, 'Medium'),
#  (10465, 'Medium'),
#  (10465, 'Small'),
#  (10465, 'Medium'),
#  (10465, 'Medium'),
#  (10465, 'Medium'),
#  (10466, 'Small'),
#  (10466, 'Small'),
#  (10467, 'Medium'),
#  (10467, 'Small'),
#  (10468, 'Small'),
#  (10468, 'Small'),
#  (10469, 'Medium'),
#  (10469, 'Medium'),
#  (10469, 'Small'),
#  (10470, 'Medium'),
#  (10470, 'Small'),
#  (10470, 'Small'),
#  (10471, 'Medium'),
#  (10471, 'Medium'),
#  (10472, 'Medium'),
#  (10472, 'Small'),
#  (10473, 'Small'),
#  (10473, 'Small'),
#  (10474, 'Small'),
#  (10474, 'Small'),
#  (10474, 'Medium'),
#  (10474, 'Small'),
#  (10475, 'Medium'),
#  (10475, 'Medium'),
#  (10475, 'Medium'),
#  (10476, 'Small'),
#  (10476, 'Small'),
#  (10477, 'Small'),
#  (10477, 'Medium'),
#  (10477, 'Medium'),
#  (10478, 'Medium'),
#  (10610, 'Medium'),
#  (10611, 'Small'),
#  (10611, 'Small'),
#  (10611, 'Small'),
#  (10612, 'Medium'),
#  (10612, 'Medium'),
#  (10612, 'Small'),
#  (10612, 'Medium'),
#  (10612, 'Medium'),
#  (10613, 'Small'),
#  (10613, 'Medium'),
#  (10614, 'Small'),
#  (10614, 'Small'),
#  (10614, 'Small'),
#  (10615, 'Small'),
#  (10616, 'Small'),
#  (10616, 'Small'),
#  (10616, 'Small'),
#  (10616, 'Small'),
#  (10617, 'Medium'),
#  (10618, 'Medium'),
#  (10618, 'Medium'),
#  (10618, 'Small'),
#  (10619, 'Medium'),
#  (10619, 'Medium'),
#  (10620, 'Small'),
#  (10620, 'Small'),
#  (10621, 'Small'),
#  (10621, 'Small'),
#  (10621, 'Medium'),
#  (10621, 'Small'),
#  (10622, 'Medium'),
#  (10622, 'Small'),
#  (10623, 'Medium'),
#  (10623, 'Small'),
#  (10623, 'Medium'),
#  (10623, 'Small'),
#  (10623, 'Medium'),
#  (10624, 'Small'),
#  (10624, 'Small'),
#  (10624, 'Small'),
#  (10625, 'Small'),
#  (10625, 'Small'),
#  (10625, 'Small'),
#  ...]

# %% [markdown]
# ### 3. Replace country if `NULL`
#
# Suppose some records in the `Customers` table have null values in the `Country` column. Write a SQL query that retrieves all customers, and if the country of a customer is `NULL`, replace it with the text 'Not Provided'.

# %%
# %%sql
# SELECT
#     CustomerID,
#     IFNULL(Country, "Not Provided") AS New_Country
# FROM
#     Customers;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('ALFKI', 'Germany'),
#  ('ANATR', 'Mexico'),
#  ('ANTON', 'Mexico'),
#  ('AROUT', 'UK'),
#  ('BERGS', 'Sweden'),
#  ('BLAUS', 'Germany'),
#  ('BLONP', 'France'),
#  ('BOLID', 'Spain'),
#  ('BONAP', 'France'),
#  ('BOTTM', 'Canada'),
#  ('BSBEV', 'UK'),
#  ('CACTU', 'Argentina'),
#  ('CENTC', 'Mexico'),
#  ('CHOPS', 'Switzerland'),
#  ('COMMI', 'Brazil'),
#  ('CONSH', 'UK'),
#  ('DRACD', 'Germany'),
#  ('DUMON', 'France'),
#  ('EASTC', 'UK'),
#  ('ERNSH', 'Austria'),
#  ('FAMIA', 'Brazil'),
#  ('FISSA', 'Spain'),
#  ('FOLIG', 'France'),
#  ('FOLKO', 'Sweden'),
#  ('FRANK', 'Germany'),
#  ('FRANR', 'France'),
#  ('FRANS', 'Italy'),
#  ('FURIB', 'Portugal'),
#  ('GALED', 'Spain'),
#  ('GODOS', 'Spain'),
#  ('GOURL', 'Brazil'),
#  ('GREAL', 'USA'),
#  ('GROSR', 'Venezuela'),
#  ('HANAR', 'Brazil'),
#  ('HILAA', 'Venezuela'),
#  ('HUNGC', 'USA'),
#  ('HUNGO', 'Ireland'),
#  ('ISLAT', 'UK'),
#  ('KOENE', 'Germany'),
#  ('LACOR', 'France'),
#  ('LAMAI', 'France'),
#  ('LAUGB', 'Canada'),
#  ('LAZYK', 'USA'),
#  ('LEHMS', 'Germany'),
#  ('LETSS', 'USA'),
#  ('LILAS', 'Venezuela'),
#  ('LINOD', 'Venezuela'),
#  ('LONEP', 'USA'),
#  ('MAGAA', 'Italy'),
#  ('MAISD', 'Belgium'),
#  ('MEREP', 'Canada'),
#  ('MORGK', 'Germany'),
#  ('NORTS', 'UK'),
#  ('OCEAN', 'Argentina'),
#  ('OLDWO', 'USA'),
#  ('OTTIK', 'Germany'),
#  ('PARIS', 'France'),
#  ('PERIC', 'Mexico'),
#  ('PICCO', 'Austria'),
#  ('PRINI', 'Portugal'),
#  ('QUEDE', 'Brazil'),
#  ('QUEEN', 'Brazil'),
#  ('QUICK', 'Germany'),
#  ('RANCH', 'Argentina'),
#  ('RATTC', 'USA'),
#  ('REGGC', 'Italy'),
#  ('RICAR', 'Brazil'),
#  ('RICSU', 'Switzerland'),
#  ('ROMEY', 'Spain'),
#  ('SANTG', 'Norway'),
#  ('SAVEA', 'USA'),
#  ('SEVES', 'UK'),
#  ('SIMOB', 'Denmark'),
#  ('SPECD', 'France'),
#  ('SPLIR', 'USA'),
#  ('SUPRD', 'Belgium'),
#  ('THEBI', 'USA'),
#  ('THECR', 'USA'),
#  ('TOMSP', 'Germany'),
#  ('TORTU', 'Mexico'),
#  ('TRADH', 'Brazil'),
#  ('TRAIH', 'USA'),
#  ('VAFFE', 'Denmark'),
#  ('Val2 ', 'Not Provided'),
#  ('VALON', 'Not Provided'),
#  ('VICTE', 'France'),
#  ('VINET', 'France'),
#  ('WANDK', 'Germany'),
#  ('WARTH', 'Finland'),
#  ('WELLI', 'Brazil'),
#  ('WHITC', 'USA'),
#  ('WILMK', 'Finland'),
#  ('WOLZA', 'Poland')]

# %% [markdown]
# ### 4. Calculate the average price of products
#
# Using the `Products` table, write a SQL query that calculates the average unit price of all products. Then, for each product, show its name, unit price, and a column `Price Comparison` that shows whether its price is 'Below Average', 'Average', or 'Above Average'.

# %%
# %%sql
#
# SELECT
#     ProductName,
#     UnitPrice,
#     CASE
#         WHEN UnitPrice < (SELECT AVG(UnitPrice) FROM Products) THEN 'Below Average'
#         WHEN UnitPrice = (SELECT AVG(UnitPrice) FROM Products) THEN 'Average'
#         ELSE 'Above Average'
#     END as PriceComparison
# FROM
#     Products;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Chai', 18, 'Below Average'),
#  ('Chang', 19, 'Below Average'),
#  ('Aniseed Syrup', 10, 'Below Average'),
#  ("Chef Anton's Cajun Seasoning", 22, 'Below Average'),
#  ("Chef Anton's Gumbo Mix", 21.35, 'Below Average'),
#  ("Grandma's Boysenberry Spread", 25, 'Below Average'),
#  ("Uncle Bob's Organic Dried Pears", 30, 'Above Average'),
#  ('Northwoods Cranberry Sauce', 40, 'Above Average'),
#  ('Mishi Kobe Niku', 97, 'Above Average'),
#  ('Ikura', 31, 'Above Average'),
#  ('Queso Cabrales', 21, 'Below Average'),
#  ('Queso Manchego La Pastora', 38, 'Above Average'),
#  ('Konbu', 6, 'Below Average'),
#  ('Tofu', 23.25, 'Below Average'),
#  ('Genen Shouyu', 15.5, 'Below Average'),
#  ('Pavlova', 17.45, 'Below Average'),
#  ('Alice Mutton', 39, 'Above Average'),
#  ('Carnarvon Tigers', 62.5, 'Above Average'),
#  ('Teatime Chocolate Biscuits', 9.2, 'Below Average'),
#  ("Sir Rodney's Marmalade", 81, 'Above Average'),
#  ("Sir Rodney's Scones", 10, 'Below Average'),
#  ("Gustaf's Knckebrd", 21, 'Below Average'),
#  ('Tunnbrd', 9, 'Below Average'),
#  ('Guaran Fantstica', 4.5, 'Below Average'),
#  ('NuNuCa Nu-Nougat-Creme', 14, 'Below Average'),
#  ('Gumbr Gummibrchen', 31.23, 'Above Average'),
#  ('Schoggi Schokolade', 43.9, 'Above Average'),
#  ('Rssle Sauerkraut', 45.6, 'Above Average'),
#  ('Thringer Rostbratwurst', 123.79, 'Above Average'),
#  ('Nord-Ost Matjeshering', 25.89, 'Below Average'),
#  ('Gorgonzola Telino', 12.5, 'Below Average'),
#  ('Mascarpone Fabioli', 32, 'Above Average'),
#  ('Geitost', 2.5, 'Below Average'),
#  ('Sasquatch Ale', 14, 'Below Average'),
#  ('Steeleye Stout', 18, 'Below Average'),
#  ('Inlagd Sill', 19, 'Below Average'),
#  ('Gravad lax', 26, 'Below Average'),
#  ('Cte de Blaye', 263.5, 'Above Average'),
#  ('Chartreuse verte', 18, 'Below Average'),
#  ('Boston Crab Meat', 18.4, 'Below Average'),
#  ("Jack's New England Clam Chowder", 9.65, 'Below Average'),
#  ('Singaporean Hokkien Fried Mee', 14, 'Below Average'),
#  ('Ipoh Coffee', 46, 'Above Average'),
#  ('Gula Malacca', 19.45, 'Below Average'),
#  ('Rogede sild', 9.5, 'Below Average'),
#  ('Spegesild', 12, 'Below Average'),
#  ('Zaanse koeken', 9.5, 'Below Average'),
#  ('Chocolade', 12.75, 'Below Average'),
#  ('Maxilaku', 20, 'Below Average'),
#  ('Valkoinen suklaa', 16.25, 'Below Average'),
#  ('Manjimup Dried Apples', 53, 'Above Average'),
#  ('Filo Mix', 7, 'Below Average'),
#  ('Perth Pasties', 32.8, 'Above Average'),
#  ('Tourtire', 7.45, 'Below Average'),
#  ('Pt chinois', 24, 'Below Average'),
#  ('Gnocchi di nonna Alice', 38, 'Above Average'),
#  ('Ravioli Angelo', 19.5, 'Below Average'),
#  ('Escargots de Bourgogne', 13.25, 'Below Average'),
#  ('Raclette Courdavault', 55, 'Above Average'),
#  ('Camembert Pierrot', 34, 'Above Average'),
#  ("Sirop d'rable", 28.5, 'Below Average'),
#  ('Tarte au sucre', 49.3, 'Above Average'),
#  ('Vegie-spread', 43.9, 'Above Average'),
#  ('Wimmers gute Semmelkndel', 33.25, 'Above Average'),
#  ('Louisiana Fiery Hot Pepper Sauce', 21.05, 'Below Average'),
#  ('Louisiana Hot Spiced Okra', 17, 'Below Average'),
#  ('Laughing Lumberjack Lager', 14, 'Below Average'),
#  ('Scottish Longbreads', 12.5, 'Below Average'),
#  ('Gudbrandsdalsost', 36, 'Above Average'),
#  ('Outback Lager', 15, 'Below Average'),
#  ('Flotemysost', 21.5, 'Below Average'),
#  ('Mozzarella di Giovanni', 34.8, 'Above Average'),
#  ('Rd Kaviar', 15, 'Below Average'),
#  ('Longlife Tofu', 10, 'Below Average'),
#  ('Rhnbru Klosterbier', 7.75, 'Below Average'),
#  ('Lakkalikri', 18, 'Below Average'),
#  ('Original Frankfurter grne Soe', 13, 'Below Average')]

# %% [markdown]
# ### 5. Identify top management employees
#
# In the `Employees` table, assume the `ReportsTo` column has some null values which represent the highest-level employees (such as a CEO). Write a SQL query to list all employees and display a new column `Position` that labels the employee as 'Top Management' if the `ReportsTo` column is `NULL`, and 'Staff' otherwise.

# %%
# %%sql
#
# SELECT
#     FirstName,
#     LastName,
#     IIF(ReportsTo IS NULL, 'Top Management', 'Staff') as Position
# FROM
#     Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy', 'Davolio', 'Staff'),
#  ('Andrew', 'Fuller', 'Top Management'),
#  ('Janet', 'Leverling', 'Staff'),
#  ('Margaret', 'Peacock', 'Staff'),
#  ('Steven', 'Buchanan', 'Staff'),
#  ('Michael', 'Suyama', 'Staff'),
#  ('Robert', 'King', 'Staff'),
#  ('Laura', 'Callahan', 'Staff'),
#  ('Anne', 'Dodsworth', 'Staff')]

# %% [markdown]
# ### Challenge question
#
# You are working with a products inventory database which has a Products table with the following columns:
#
# - `ProductID`
# - `ProductName`
# - `UnitPrice`
# - `UnitsInStock`
# - `ReorderLevel`
# - `SupplierCountry`
#
# Your manager wants to assess the company's stock levels and has asked for your assistance.

# %% [markdown]
# Write a SQL query that retrieves the following information:
#
# - `ProductName`
# - `UnitPrice`
# - `UnitsInStock`
# - A column `StockStatus` that categorises the stock level of each product as 'Low', 'Medium', or 'High' based on the `UnitsInStock` (Use a `CASE` statement to create this column where 'Low' is less than 20 units, 'Medium' is between 20 and 50 units, 'High' is over 50 units).
# - A column `PriceLevel` that categorises the price of each product as 'Cheap', 'Affordable', or 'Expensive' based on the `UnitPrice` (Use a `CASE` statement to create this column where 'Cheap' is less than \$10, 'Affordable' is between \$10 and \$50, 'Expensive' is over \$50).
#
# Your SQL query should consider the use of aggregation functions, date functions, control flow functions, and string functions.

# %%
# %%sql
#
# SELECT
#     ProductName,
#     UnitsInStock,
#     UnitPrice,
#     CASE
#         WHEN UnitsInStock < 20 THEN 'Low'
#         WHEN UnitsInStock BETWEEN 20 AND 50 THEN 'Medium'
#         ELSE 'High'
#     END AS StockStatus,
#     CASE
#         WHEN UnitPrice < 10 THEN 'Cheap'
#         WHEN UnitPrice BETWEEN 10 AND 50 THEN 'Affordable'
#         ELSE 'Expensive'
#     END AS PriceLevel
# FROM
#     Products;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Chai', 39, 18, 'Medium', 'Affordable'),
#  ('Chang', 17, 19, 'Low', 'Affordable'),
#  ('Aniseed Syrup', 13, 10, 'Low', 'Affordable'),
#  ("Chef Anton's Cajun Seasoning", 53, 22, 'High', 'Affordable'),
#  ("Chef Anton's Gumbo Mix", 0, 21.35, 'Low', 'Affordable'),
#  ("Grandma's Boysenberry Spread", 120, 25, 'High', 'Affordable'),
#  ("Uncle Bob's Organic Dried Pears", 15, 30, 'Low', 'Affordable'),
#  ('Northwoods Cranberry Sauce', 6, 40, 'Low', 'Affordable'),
#  ('Mishi Kobe Niku', 29, 97, 'Medium', 'Expensive'),
#  ('Ikura', 31, 31, 'Medium', 'Affordable'),
#  ('Queso Cabrales', 22, 21, 'Medium', 'Affordable'),
#  ('Queso Manchego La Pastora', 86, 38, 'High', 'Affordable'),
#  ('Konbu', 24, 6, 'Medium', 'Cheap'),
#  ('Tofu', 35, 23.25, 'Medium', 'Affordable'),
#  ('Genen Shouyu', 39, 15.5, 'Medium', 'Affordable'),
#  ('Pavlova', 29, 17.45, 'Medium', 'Affordable'),
#  ('Alice Mutton', 0, 39, 'Low', 'Affordable'),
#  ('Carnarvon Tigers', 42, 62.5, 'Medium', 'Expensive'),
#  ('Teatime Chocolate Biscuits', 25, 9.2, 'Medium', 'Cheap'),
#  ("Sir Rodney's Marmalade", 40, 81, 'Medium', 'Expensive'),
#  ("Sir Rodney's Scones", 3, 10, 'Low', 'Affordable'),
#  ("Gustaf's Knckebrd", 104, 21, 'High', 'Affordable'),
#  ('Tunnbrd', 61, 9, 'High', 'Cheap'),
#  ('Guaran Fantstica', 20, 4.5, 'Medium', 'Cheap'),
#  ('NuNuCa Nu-Nougat-Creme', 76, 14, 'High', 'Affordable'),
#  ('Gumbr Gummibrchen', 15, 31.23, 'Low', 'Affordable'),
#  ('Schoggi Schokolade', 49, 43.9, 'Medium', 'Affordable'),
#  ('Rssle Sauerkraut', 26, 45.6, 'Medium', 'Affordable'),
#  ('Thringer Rostbratwurst', 0, 123.79, 'Low', 'Expensive'),
#  ('Nord-Ost Matjeshering', 10, 25.89, 'Low', 'Affordable'),
#  ('Gorgonzola Telino', 0, 12.5, 'Low', 'Affordable'),
#  ('Mascarpone Fabioli', 9, 32, 'Low', 'Affordable'),
#  ('Geitost', 112, 2.5, 'High', 'Cheap'),
#  ('Sasquatch Ale', 111, 14, 'High', 'Affordable'),
#  ('Steeleye Stout', 20, 18, 'Medium', 'Affordable'),
#  ('Inlagd Sill', 112, 19, 'High', 'Affordable'),
#  ('Gravad lax', 11, 26, 'Low', 'Affordable'),
#  ('Cte de Blaye', 17, 263.5, 'Low', 'Expensive'),
#  ('Chartreuse verte', 69, 18, 'High', 'Affordable'),
#  ('Boston Crab Meat', 123, 18.4, 'High', 'Affordable'),
#  ("Jack's New England Clam Chowder", 85, 9.65, 'High', 'Cheap'),
#  ('Singaporean Hokkien Fried Mee', 26, 14, 'Medium', 'Affordable'),
#  ('Ipoh Coffee', 17, 46, 'Low', 'Affordable'),
#  ('Gula Malacca', 27, 19.45, 'Medium', 'Affordable'),
#  ('Rogede sild', 5, 9.5, 'Low', 'Cheap'),
#  ('Spegesild', 95, 12, 'High', 'Affordable'),
#  ('Zaanse koeken', 36, 9.5, 'Medium', 'Cheap'),
#  ('Chocolade', 15, 12.75, 'Low', 'Affordable'),
#  ('Maxilaku', 10, 20, 'Low', 'Affordable'),
#  ('Valkoinen suklaa', 65, 16.25, 'High', 'Affordable'),
#  ('Manjimup Dried Apples', 20, 53, 'Medium', 'Expensive'),
#  ('Filo Mix', 38, 7, 'Medium', 'Cheap'),
#  ('Perth Pasties', 0, 32.8, 'Low', 'Affordable'),
#  ('Tourtire', 21, 7.45, 'Medium', 'Cheap'),
#  ('Pt chinois', 115, 24, 'High', 'Affordable'),
#  ('Gnocchi di nonna Alice', 21, 38, 'Medium', 'Affordable'),
#  ('Ravioli Angelo', 36, 19.5, 'Medium', 'Affordable'),
#  ('Escargots de Bourgogne', 62, 13.25, 'High', 'Affordable'),
#  ('Raclette Courdavault', 79, 55, 'High', 'Expensive'),
#  ('Camembert Pierrot', 19, 34, 'Low', 'Affordable'),
#  ("Sirop d'rable", 113, 28.5, 'High', 'Affordable'),
#  ('Tarte au sucre', 17, 49.3, 'Low', 'Affordable'),
#  ('Vegie-spread', 24, 43.9, 'Medium', 'Affordable'),
#  ('Wimmers gute Semmelkndel', 22, 33.25, 'Medium', 'Affordable'),
#  ('Louisiana Fiery Hot Pepper Sauce', 76, 21.05, 'High', 'Affordable'),
#  ('Louisiana Hot Spiced Okra', 4, 17, 'Low', 'Affordable'),
#  ('Laughing Lumberjack Lager', 52, 14, 'High', 'Affordable'),
#  ('Scottish Longbreads', 6, 12.5, 'Low', 'Affordable'),
#  ('Gudbrandsdalsost', 26, 36, 'Medium', 'Affordable'),
#  ('Outback Lager', 15, 15, 'Low', 'Affordable'),
#  ('Flotemysost', 26, 21.5, 'Medium', 'Affordable'),
#  ('Mozzarella di Giovanni', 14, 34.8, 'Low', 'Affordable'),
#  ('Rd Kaviar', 101, 15, 'High', 'Affordable'),
#  ('Longlife Tofu', 4, 10, 'Low', 'Affordable'),
#  ('Rhnbru Klosterbier', 125, 7.75, 'High', 'Cheap'),
#  ('Lakkalikri', 57, 18, 'High', 'Affordable'),
#  ('Original Frankfurter grne Soe', 32, 13, 'Medium', 'Affordable')]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Categorise employees based on salaries
#
# This query uses the `IIF` control function to check if each employee's salary is greater than 50,000. If it is, the function returns 'Yes', otherwise 'No'. This result is displayed in the new column `HighSalary`.
#
# Expected outcome: A table with columns `FirstName`, `LastName`, and `HighSalary`. The `HighSalary` column displays 'Yes' or 'No' depending on each employee's salary.
#
# **NOTE:** The `IF` function is not supported in SQLite, so we use the `IIF` function which is the SQLite equivalent for `IF`.

# %%
# %%sql
#
# SELECT
#        FirstName,
#        LastName,
#        IIF(Salary > 50000, 'Yes', 'No') AS HighSalary
# FROM
#        Employees;

# %% [markdown]
# ### 2. Categorise orders based on quantity
#
# This query uses the `CASE` statement to categorise the size of each order. If the quantity of an order is less than 20, it's categorised as 'Small'. If it's between 20 and 100, it's 'Medium'. Otherwise, it's 'Large'.
#
# Expected outcome: A table with columns `OrderID` and `OrderSize`. The `OrderSize` column displays 'Small', 'Medium', or 'Large' depending on each order's quantity.

# %%
# %%sql
#
# SELECT
#     OrderID,
#     CASE
#         WHEN (Quantity < 20) THEN 'Small'
#         WHEN Quantity BETWEEN 20 AND 100 THEN 'Medium'
#         ELSE 'Large'
#     END as OrderSize
# FROM
#     OrderDetails;

# %% [markdown]
# ### 3. Replace country if `NULL`
#
# This query uses the `IFNULL` function to replace null values in the `Country` column with 'Not Provided'.
#
# Expected outcome: A table with columns `CustomerID`, `CompanyName`, and `Country`. The `Country` column displays the name of the country or 'Not Provided' if the original value was `NULL`.

# %%
# %%sql
#
# SELECT
#     CustomerID,
#     CompanyName,
#     IFNULL(Country, 'Not Provided') AS Country
# FROM
#     Customers;

# %% [markdown]
# ### 4. Calculate the average price of products
#
# This query calculates the average unit price of all products. Then, it compares the unit price of each product with this average and labels it as 'Below Average', 'Average', or 'Above Average' accordingly.
#
# Expected outcome: A table with columns `ProductName`, `UnitPrice`, and `PriceComparison`. The `PriceComparison` column displays 'Below Average', 'Average', or 'Above Average' depending on each product's unit price.

# %%
# %%sql
#
# SELECT
#     ProductName,
#     UnitPrice,
#     CASE
#         WHEN UnitPrice < (SELECT AVG(UnitPrice) FROM Products) THEN 'Below Average'
#         WHEN UnitPrice = (SELECT AVG(UnitPrice) FROM Products) THEN 'Average'
#         ELSE 'Above Average'
#     END as PriceComparison
# FROM
#     Products;

# %% [markdown]
# ### 5. Identify top management employees
#
# This query uses the `IIF` function to check if the `ReportsTo` field of an employee is `NULL`. If it is, the employee is labelled as 'Top Management', otherwise 'Staff'.
#
# Expected outcome: A table with columns `FirstName`, `LastName`, and `Position`. The `Position` column displays 'Top Management' or 'Staff' depending on the `ReportsTo` field of each employee.

# %%
# %%sql
#
# SELECT
#     FirstName,
#     LastName,
#     IIF(ReportsTo IS NULL, 'Top Management', 'Staff') as Position
# FROM
#     Employees;

# %% [markdown]
# ### Challenge question
#
# This problem requires the integration of SQL querying with some basic logic and control flow.
#
# Here is a step-by-step breakdown of how to approach solving this problem:

# %% [markdown]
# 1. **Identify required fields:** The first part of the problem is straightforward. We're being asked to retrieve `ProductName`, `UnitsInStock`, and `UnitPrice` from our `Products` table. These fields can be directly selected in our SQL query.
#
# 2. **Categorise stock levels:** We need to create a new field, `StockStatus`, that categorises the stock level based on the `UnitsInStock`. This requires the use of a control flow function – specifically, a `CASE` statement. The `CASE` statement allows us to conditionally return results based on the value of another field. In this case, we will categorise `UnitsInStock` as 'Low' if less than 20, 'Medium' if between 20 and 50, and 'High' if more than 50.
#
# 3. **Categorise price levels:** Similarly, we need to create another field, `PriceLevel`, that categorises the price of a product based on the `UnitPrice`. We'll again use a `CASE` statement to accomplish this. We will categorise `UnitPrice` as *Cheap* if less than \$10, *Affordable* if between \$10 and \$50, and *Expensive* if more than \$50.

# %% [markdown]
# So, to solve the problem, we would write a SQL query that selects the required fields and uses `CASE` statements to create the new `StockStatus` and `PriceLevel` fields based on the conditions described above.
#
# In SQL, this would look something like:

# %%
# %%sql
#
# SELECT
#     ProductName,
#     UnitsInStock,
#     UnitPrice,
#     CASE
#         WHEN UnitsInStock < 20 THEN 'Low'
#         WHEN UnitsInStock BETWEEN 20 AND 50 THEN 'Medium'
#         ELSE 'High'
#     END AS StockStatus,
#     CASE
#         WHEN UnitPrice < 10 THEN 'Cheap'
#         WHEN UnitPrice BETWEEN 10 AND 50 THEN 'Affordable'
#         ELSE 'Expensive'
#     END AS PriceLevel
# FROM
#     Products;

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
