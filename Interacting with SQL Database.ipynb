# %%
#Preparing the Environment 
#Must be run once everytime the kernel is restarted
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://root:4211210116@127.0.0.1:3306/md_water_services
#Must also be connected everytime the notebook to lauched to establish a connection
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: root@md_water_services'

# %%
# %%sql
# SELECT *
# FROM md_water_services.global_water_access
# WHERE pop_n > 3000;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/md_water_services
# 272 rows affected.
# [('Afghanistan', 'South Asia', 2015, 34413.6, 24.803, 61.3398, 3.5112, 22.1688, 12.9802, 52.9885, 3.86114, 26.5533, 16.5971, 86.6589, 2.45027, 8.87604, 2.01475),
#  ('Afghanistan', 'South Asia', 2020, 38928.3, 26.026, 75.0914, 1.44754, 14.5603, 8.90078, 66.3279, 1.95682, 19.6829, 12.0323, 100.0, 0.0, 0.0, 0.0),
#  ('Algeria', 'Middle East & North Africa', 2015, 39728.0, 70.848, 93.4096, 5.15778, 1.27546, 0.157193, 88.3527, 8.68575, 2.58043, 0.381108, 95.4903, 3.70612, 0.73851, 0.0650579),
#  ('Algeria', 'Middle East & North Africa', 2020, 43851.0, 73.733, 94.4373, 4.98588, 0.531837, 0.0449525, 90.0375, 8.79672, 0.994603, 0.171137, 96.0047, 3.62829, 0.366976, 0.0),
#  ('Angola', 'Sub-Saharan Africa', 2015, 27884.4, 63.446, 54.3169, 11.3686, 17.3724, 16.9421, 26.7144, 9.93107, 21.7253, 41.6293, 70.22, 12.1969, 14.8644, 2.71875),
# ...
