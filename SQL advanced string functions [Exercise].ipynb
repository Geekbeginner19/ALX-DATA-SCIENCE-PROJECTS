# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # SQL advanced string functions

# %% [markdown]
# In this exercise, we will use the skills we have learned so far to solve complex problems that involve string manipulation and handling. Ensure that you have downloaded the database file, Northwind.db.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will:
# - Understand how to apply  SQL functions for data type conversion, null value handling, and string manipulation to solve complex problems.

# %% [markdown]
# First, let's load our database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
# Load the Northwind database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///Northwind.db
# Out:
# 'Connected: @Northwind.db'

# %% [markdown]
# Here is a view of all of our tables in the database:
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png"  style="width:70%";/>
# <br>
# <br>
#     <em>Figure 1: Northwind database ERD</em>
# </div>

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Convert data type
#
# Given the `Employees` table, write a SQL query to convert the salary of all employees from integer to string data type.

# %%
# %%sql
# SELECT
#     CAST(Salary AS CHAR) AS SalaryString
# FROM
#     Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('2954.55',),
#  ('2254.49',),
#  ('3119.15',),
#  ('1861.08',),
#  ('1744.21',),
#  ('2004.07',),
#  ('1991.55',),
#  ('2100.5',),
#  ('2333.33',)]

# %% [markdown]
# ### 2. Trim strings
#
# In the `Orders` table, some of the `ShipName` entries have leading and trailing white spaces. Write a SQL query to trim these white spaces.

# %%
# %%sql
# SELECT
#     ShipName,
#     LENGTH(ShipName) AS Length_ShipNames,
#     TRIM(ShipName) AS Trimed_ShipNames,
#     LENGTH(TRIM(ShipName)) AS Length_Trimed_ShipNames
# FROM
#     Orders;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Vins et alcools Chevalier', 25, 'Vins et alcools Chevalier', 25),
#  ('Toms Spezialitten', 17, 'Toms Spezialitten', 17),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('Victuailles en stock', 20, 'Victuailles en stock', 20),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('Chop-suey Chinese', 17, 'Chop-suey Chinese', 17),
#  ('Richter Supermarkt', 18, 'Richter Supermarkt', 18),
#  ('Wellington Importadora', 22, 'Wellington Importadora', 22),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Centro comercial Moctezuma', 26, 'Centro comercial Moctezuma', 26),
#  ('Ottilies Kseladen', 17, 'Ottilies Kseladen', 17),
#  ('Que Delcia', 10, 'Que Delcia', 10),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('GROSELLA-Restaurante', 20, 'GROSELLA-Restaurante', 20),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Split Rail Beer & Ale', 21, 'Split Rail Beer & Ale', 21),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Vins et alcools Chevalier', 25, 'Vins et alcools Chevalier', 25),
#  ('Magazzini Alimentari Riuniti', 28, 'Magazzini Alimentari Riuniti', 28),
#  ('Tortuga Restaurante', 19, 'Tortuga Restaurante', 19),
#  ('Morgenstern Gesundkost', 22, 'Morgenstern Gesundkost', 22),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Romero y tomillo', 16, 'Romero y tomillo', 16),
#  ('Romero y tomillo', 16, 'Romero y tomillo', 16),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('B-s Beverages', 13, 'B-s Beverages', 13),
#  ('Comrcio Mineiro', 15, 'Comrcio Mineiro', 15),
#  ('Que Delcia', 10, 'Que Delcia', 10),
#  ('Tradiao Hipermercados', 21, 'Tradiao Hipermercados', 21),
#  ('Tortuga Restaurante', 19, 'Tortuga Restaurante', 19),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Vins et alcools Chevalier', 25, 'Vins et alcools Chevalier', 25),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('Magazzini Alimentari Riuniti', 28, 'Magazzini Alimentari Riuniti', 28),
#  ('Die Wandernde Kuh', 17, 'Die Wandernde Kuh', 17),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('Godos Cocina Tpica', 18, 'Godos Cocina Tpica', 18),
#  ('Tortuga Restaurante', 19, 'Tortuga Restaurante', 19),
#  ('Old World Delicatessen', 22, 'Old World Delicatessen', 22),
#  ('Romero y tomillo', 16, 'Romero y tomillo', 16),
#  ('Lonesome Pine Restaurant', 24, 'Lonesome Pine Restaurant', 24),
#  ('Ana Trujillo Emparedados y helados', 34, 'Ana Trujillo Emparedados y helados', 34),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('The Big Cheese', 14, 'The Big Cheese', 14),
#  ('Du monde entier', 15, 'Du monde entier', 15),
#  ('Die Wandernde Kuh', 17, 'Die Wandernde Kuh', 17),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Island Trading', 14, 'Island Trading', 14),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Lonesome Pine Restaurant', 24, 'Lonesome Pine Restaurant', 24),
#  ('Island Trading', 14, 'Island Trading', 14),
#  ('Tortuga Restaurante', 19, 'Tortuga Restaurante', 19),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Island Trading', 14, 'Island Trading', 14),
#  ('Pericles Comidas clsicas', 24, 'Pericles Comidas clsicas', 24),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Blido Comidas preparadas', 24, 'Blido Comidas preparadas', 24),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Furia Bacalhau e Frutos do Mar', 30, 'Furia Bacalhau e Frutos do Mar', 30),
#  ('Split Rail Beer & Ale', 21, 'Split Rail Beer & Ale', 21),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Victuailles en stock', 20, 'Victuailles en stock', 20),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Princesa Isabel Vinhos', 22, 'Princesa Isabel Vinhos', 22),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Old World Delicatessen', 22, 'Old World Delicatessen', 22),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Simons bistro', 13, 'Simons bistro', 13),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Familia Arquibaldo', 18, 'Familia Arquibaldo', 18),
#  ('Die Wandernde Kuh', 17, 'Die Wandernde Kuh', 17),
#  ('Split Rail Beer & Ale', 21, 'Split Rail Beer & Ale', 21),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Furia Bacalhau e Frutos do Mar', 30, 'Furia Bacalhau e Frutos do Mar', 30),
#  ('Piccolo und mehr', 16, 'Piccolo und mehr', 16),
#  ('Pericles Comidas clsicas', 24, 'Pericles Comidas clsicas', 24),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('Die Wandernde Kuh', 17, 'Die Wandernde Kuh', 17),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Seven Seas Imports', 18, 'Seven Seas Imports', 18),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Drachenblut Delikatessen', 24, 'Drachenblut Delikatessen', 24),
#  ('Eastern Connection', 18, 'Eastern Connection', 18),
#  ('Antonio Moreno Taquera', 22, 'Antonio Moreno Taquera', 22),
#  ('Galera del gastronmo', 20, 'Galera del gastronmo', 20),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Split Rail Beer & Ale', 21, 'Split Rail Beer & Ale', 21),
#  ('Chop-suey Chinese', 17, 'Chop-suey Chinese', 17),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Wolski Zajazd', 13, 'Wolski Zajazd', 13),
#  ('Hungry Coyote Import Store', 26, 'Hungry Coyote Import Store', 26),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Seven Seas Imports', 18, 'Seven Seas Imports', 18),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Que Delcia', 10, 'Que Delcia', 10),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Split Rail Beer & Ale', 21, 'Split Rail Beer & Ale', 21),
#  ('Familia Arquibaldo', 18, 'Familia Arquibaldo', 18),
#  ('Sant Gourmet', 12, 'Sant Gourmet', 12),
#  ('Seven Seas Imports', 18, 'Seven Seas Imports', 18),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Drachenblut Delikatessen', 24, 'Drachenblut Delikatessen', 24),
#  ('Piccolo und mehr', 16, 'Piccolo und mehr', 16),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Hungry Coyote Import Store', 26, 'Hungry Coyote Import Store', 26),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Princesa Isabel Vinhos', 22, 'Princesa Isabel Vinhos', 22),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('Eastern Connection', 18, 'Eastern Connection', 18),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Magazzini Alimentari Riuniti', 28, 'Magazzini Alimentari Riuniti', 28),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('Ottilies Kseladen', 17, 'Ottilies Kseladen', 17),
#  ('Folies gourmandes', 17, 'Folies gourmandes', 17),
#  ('Ocano Atlntico Ltda.', 20, 'Ocano Atlntico Ltda.', 20),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Familia Arquibaldo', 18, 'Familia Arquibaldo', 18),
#  ('Hungry Coyote Import Store', 26, 'Hungry Coyote Import Store', 26),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Simons bistro', 13, 'Simons bistro', 13),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Richter Supermarkt', 18, 'Richter Supermarkt', 18),
#  ('Wellington Importadora', 22, 'Wellington Importadora', 22),
#  ('Que Delcia', 10, 'Que Delcia', 10),
#  ('Franchi S.p.A.', 14, 'Franchi S.p.A.', 14),
#  ('Gourmet Lanchonetes', 19, 'Gourmet Lanchonetes', 19),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Galera del gastronmo', 20, 'Galera del gastronmo', 20),
#  ('Piccolo und mehr', 16, 'Piccolo und mehr', 16),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Split Rail Beer & Ale', 21, 'Split Rail Beer & Ale', 21),
#  ('Princesa Isabel Vinhos', 22, 'Princesa Isabel Vinhos', 22),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Consolidated Holdings', 21, 'Consolidated Holdings', 21),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Toms Spezialitten', 17, 'Toms Spezialitten', 17),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Old World Delicatessen', 22, 'Old World Delicatessen', 22),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Toms Spezialitten', 17, 'Toms Spezialitten', 17),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('Rancho grande', 13, 'Rancho grande', 13),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('Victuailles en stock', 20, 'Victuailles en stock', 20),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('Victuailles en stock', 20, 'Victuailles en stock', 20),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Consolidated Holdings', 21, 'Consolidated Holdings', 21),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('Furia Bacalhau e Frutos do Mar', 30, 'Furia Bacalhau e Frutos do Mar', 30),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('Comrcio Mineiro', 15, 'Comrcio Mineiro', 15),
#  ('Magazzini Alimentari Riuniti', 28, 'Magazzini Alimentari Riuniti', 28),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('B-s Beverages', 13, 'B-s Beverages', 13),
#  ('Seven Seas Imports', 18, 'Seven Seas Imports', 18),
#  ('Island Trading', 14, 'Island Trading', 14),
#  ('Pericles Comidas clsicas', 24, 'Pericles Comidas clsicas', 24),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Princesa Isabel Vinhos', 22, 'Princesa Isabel Vinhos', 22),
#  ('Victuailles en stock', 20, 'Victuailles en stock', 20),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Folies gourmandes', 17, 'Folies gourmandes', 17),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('Lazy K Kountry Store', 20, 'Lazy K Kountry Store', 20),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('B-s Beverages', 13, 'B-s Beverages', 13),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Piccolo und mehr', 16, 'Piccolo und mehr', 16),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Furia Bacalhau e Frutos do Mar', 30, 'Furia Bacalhau e Frutos do Mar', 30),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Comrcio Mineiro', 15, 'Comrcio Mineiro', 15),
#  ('Laughing Bacchus Wine Cellars', 29, 'Laughing Bacchus Wine Cellars', 29),
#  ('Tradiao Hipermercados', 21, 'Tradiao Hipermercados', 21),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Blauer See Delikatessen', 23, 'Blauer See Delikatessen', 23),
#  ('Pericles Comidas clsicas', 24, 'Pericles Comidas clsicas', 24),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Antonio Moreno Taquera', 22, 'Antonio Moreno Taquera', 22),
#  ('Ottilies Kseladen', 17, 'Ottilies Kseladen', 17),
#  ('Blauer See Delikatessen', 23, 'Blauer See Delikatessen', 23),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Familia Arquibaldo', 18, 'Familia Arquibaldo', 18),
#  ('Die Wandernde Kuh', 17, 'Die Wandernde Kuh', 17),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('North/South', 11, 'North/South', 11),
#  ('Tortuga Restaurante', 19, 'Tortuga Restaurante', 19),
#  ('Chop-suey Chinese', 17, 'Chop-suey Chinese', 17),
#  ('Sant Gourmet', 12, 'Sant Gourmet', 12),
#  ('Cactus Comidas para llevar', 26, 'Cactus Comidas para llevar', 26),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('Seven Seas Imports', 18, 'Seven Seas Imports', 18),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Maison Dewey', 12, 'Maison Dewey', 12),
#  ('Piccolo und mehr', 16, 'Piccolo und mehr', 16),
#  ('Ocano Atlntico Ltda.', 20, 'Ocano Atlntico Ltda.', 20),
#  ('Eastern Connection', 18, 'Eastern Connection', 18),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('Antonio Moreno Taquera', 22, 'Antonio Moreno Taquera', 22),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('Richter Supermarkt', 18, 'Richter Supermarkt', 18),
#  ('B-s Beverages', 13, 'B-s Beverages', 13),
#  ('B-s Beverages', 13, 'B-s Beverages', 13),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Lonesome Pine Restaurant', 24, 'Lonesome Pine Restaurant', 24),
#  ('Lazy K Kountry Store', 20, 'Lazy K Kountry Store', 20),
#  ('Victuailles en stock', 20, 'Victuailles en stock', 20),
#  ('Seven Seas Imports', 18, 'Seven Seas Imports', 18),
#  ('Toms Spezialitten', 17, 'Toms Spezialitten', 17),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Godos Cocina Tpica', 18, 'Godos Cocina Tpica', 18),
#  ('Furia Bacalhau e Frutos do Mar', 30, 'Furia Bacalhau e Frutos do Mar', 30),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Ottilies Kseladen', 17, 'Ottilies Kseladen', 17),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Simons bistro', 13, 'Simons bistro', 13),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Galera del gastronmo', 20, 'Galera del gastronmo', 20),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Antonio Moreno Taquera', 22, 'Antonio Moreno Taquera', 22),
#  ('Trail-s Head Gourmet Provisioners', 33, 'Trail-s Head Gourmet Provisioners', 33),
#  ('Morgenstern Gesundkost', 22, 'Morgenstern Gesundkost', 22),
#  ('Tortuga Restaurante', 19, 'Tortuga Restaurante', 19),
#  ('Trail-s Head Gourmet Provisioners', 33, 'Trail-s Head Gourmet Provisioners', 33),
#  ('B-s Beverages', 13, 'B-s Beverages', 13),
#  ('Let-s Stop N Shop', 17, 'Let-s Stop N Shop', 17),
#  ('Ottilies Kseladen', 17, 'Ottilies Kseladen', 17),
#  ('Familia Arquibaldo', 18, 'Familia Arquibaldo', 18),
#  ('Blauer See Delikatessen', 23, 'Blauer See Delikatessen', 23),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('Wellington Importadora', 22, 'Wellington Importadora', 22),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('Que Delcia', 10, 'Que Delcia', 10),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('Old World Delicatessen', 22, 'Old World Delicatessen', 22),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('Piccolo und mehr', 16, 'Piccolo und mehr', 16),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('B-s Beverages', 13, 'B-s Beverages', 13),
#  ('Hungry Coyote Import Store', 26, 'Hungry Coyote Import Store', 26),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Furia Bacalhau e Frutos do Mar', 30, 'Furia Bacalhau e Frutos do Mar', 30),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Tradiao Hipermercados', 21, 'Tradiao Hipermercados', 21),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Toms Spezialitten', 17, 'Toms Spezialitten', 17),
#  ('Du monde entier', 15, 'Du monde entier', 15),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Wolski Zajazd', 13, 'Wolski Zajazd', 13),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Blauer See Delikatessen', 23, 'Blauer See Delikatessen', 23),
#  ('Wilman Kala', 11, 'Wilman Kala', 11),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Laughing Bacchus Wine Cellars', 29, 'Laughing Bacchus Wine Cellars', 29),
#  ('Island Trading', 14, 'Island Trading', 14),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('The Cracker Box', 15, 'The Cracker Box', 15),
#  ('Ana Trujillo Emparedados y helados', 34, 'Ana Trujillo Emparedados y helados', 34),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('Godos Cocina Tpica', 18, 'Godos Cocina Tpica', 18),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Die Wandernde Kuh', 17, 'Die Wandernde Kuh', 17),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Folies gourmandes', 17, 'Folies gourmandes', 17),
#  ('Magazzini Alimentari Riuniti', 28, 'Magazzini Alimentari Riuniti', 28),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Sant Gourmet', 12, 'Sant Gourmet', 12),
#  ('Die Wandernde Kuh', 17, 'Die Wandernde Kuh', 17),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Simons bistro', 13, 'Simons bistro', 13),
#  ('Alfreds Futterkiste', 19, 'Alfreds Futterkiste', 19),
#  ('Wellington Importadora', 22, 'Wellington Importadora', 22),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Que Delcia', 10, 'Que Delcia', 10),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('Maison Dewey', 12, 'Maison Dewey', 12),
#  ('Familia Arquibaldo', 18, 'Familia Arquibaldo', 18),
#  ('Die Wandernde Kuh', 17, 'Die Wandernde Kuh', 17),
#  ('Gourmet Lanchonetes', 19, 'Gourmet Lanchonetes', 19),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('Hungry Coyote Import Store', 26, 'Hungry Coyote Import Store', 26),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Lonesome Pine Restaurant', 24, 'Lonesome Pine Restaurant', 24),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Furia Bacalhau e Frutos do Mar', 30, 'Furia Bacalhau e Frutos do Mar', 30),
#  ('Lonesome Pine Restaurant', 24, 'Lonesome Pine Restaurant', 24),
#  ('Richter Supermarkt', 18, 'Richter Supermarkt', 18),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Die Wandernde Kuh', 17, 'Die Wandernde Kuh', 17),
#  ('Simons bistro', 13, 'Simons bistro', 13),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('France restauration', 19, 'France restauration', 19),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Wilman Kala', 11, 'Wilman Kala', 11),
#  ('Island Trading', 14, 'Island Trading', 14),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Tortuga Restaurante', 19, 'Tortuga Restaurante', 19),
#  ('Antonio Moreno Taquera', 22, 'Antonio Moreno Taquera', 22),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('Old World Delicatessen', 22, 'Old World Delicatessen', 22),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Antonio Moreno Taquera', 22, 'Antonio Moreno Taquera', 22),
#  ('Du monde entier', 15, 'Du monde entier', 15),
#  ('Ottilies Kseladen', 17, 'Ottilies Kseladen', 17),
#  ('Gourmet Lanchonetes', 19, 'Gourmet Lanchonetes', 19),
#  ('Piccolo und mehr', 16, 'Piccolo und mehr', 16),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Alfred-s Futterkiste', 20, 'Alfred-s Futterkiste', 20),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Wilman Kala', 11, 'Wilman Kala', 11),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Morgenstern Gesundkost', 22, 'Morgenstern Gesundkost', 22),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Alfred-s Futterkiste', 20, 'Alfred-s Futterkiste', 20),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Old World Delicatessen', 22, 'Old World Delicatessen', 22),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('The Big Cheese', 14, 'The Big Cheese', 14),
#  ('Gourmet Lanchonetes', 19, 'Gourmet Lanchonetes', 19),
#  ('Franchi S.p.A.', 14, 'Franchi S.p.A.', 14),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Rancho grande', 13, 'Rancho grande', 13),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Let-s Stop N Shop', 17, 'Let-s Stop N Shop', 17),
#  ('Que Delcia', 10, 'Que Delcia', 10),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('Mre Paillarde', 13, 'Mre Paillarde', 13),
#  ('Familia Arquibaldo', 18, 'Familia Arquibaldo', 18),
#  ('Eastern Connection', 18, 'Eastern Connection', 18),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Chop-suey Chinese', 17, 'Chop-suey Chinese', 17),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Gourmet Lanchonetes', 19, 'Gourmet Lanchonetes', 19),
#  ('Let-s Stop N Shop', 17, 'Let-s Stop N Shop', 17),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Vins et alcools Chevalier', 25, 'Vins et alcools Chevalier', 25),
#  ('Spcialits du monde', 18, 'Spcialits du monde', 18),
#  ('Vins et alcools Chevalier', 25, 'Vins et alcools Chevalier', 25),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Chop-suey Chinese', 17, 'Chop-suey Chinese', 17),
#  ('Piccolo und mehr', 16, 'Piccolo und mehr', 16),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Island Trading', 14, 'Island Trading', 14),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Richter Supermarkt', 18, 'Richter Supermarkt', 18),
#  ('North/South', 11, 'North/South', 11),
#  ('Franchi S.p.A.', 14, 'Franchi S.p.A.', 14),
#  ('Magazzini Alimentari Riuniti', 28, 'Magazzini Alimentari Riuniti', 28),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Split Rail Beer & Ale', 21, 'Split Rail Beer & Ale', 21),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Richter Supermarkt', 18, 'Richter Supermarkt', 18),
#  ('Ana Trujillo Emparedados y helados', 34, 'Ana Trujillo Emparedados y helados', 34),
#  ('Maison Dewey', 12, 'Maison Dewey', 12),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Folies gourmandes', 17, 'Folies gourmandes', 17),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Ottilies Kseladen', 17, 'Ottilies Kseladen', 17),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('The Cracker Box', 15, 'The Cracker Box', 15),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Gourmet Lanchonetes', 19, 'Gourmet Lanchonetes', 19),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Morgenstern Gesundkost', 22, 'Morgenstern Gesundkost', 22),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Cactus Comidas para llevar', 26, 'Cactus Comidas para llevar', 26),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('Magazzini Alimentari Riuniti', 28, 'Magazzini Alimentari Riuniti', 28),
#  ('GROSELLA-Restaurante', 20, 'GROSELLA-Restaurante', 20),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Folies gourmandes', 17, 'Folies gourmandes', 17),
#  ('Gourmet Lanchonetes', 19, 'Gourmet Lanchonetes', 19),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Wolski Zajazd', 13, 'Wolski Zajazd', 13),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('Que Delcia', 10, 'Que Delcia', 10),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Drachenblut Delikatessen', 24, 'Drachenblut Delikatessen', 24),
#  ('Island Trading', 14, 'Island Trading', 14),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Seven Seas Imports', 18, 'Seven Seas Imports', 18),
#  ('Blido Comidas preparadas', 24, 'Blido Comidas preparadas', 24),
#  ('Simons bistro', 13, 'Simons bistro', 13),
#  ('Wellington Importadora', 22, 'Wellington Importadora', 22),
#  ('Seven Seas Imports', 18, 'Seven Seas Imports', 18),
#  ('The Big Cheese', 14, 'The Big Cheese', 14),
#  ('Victuailles en stock', 20, 'Victuailles en stock', 20),
#  ('Franchi S.p.A.', 14, 'Franchi S.p.A.', 14),
#  ('Old World Delicatessen', 22, 'Old World Delicatessen', 22),
#  ('Wellington Importadora', 22, 'Wellington Importadora', 22),
#  ('Laughing Bacchus Wine Cellars', 29, 'Laughing Bacchus Wine Cellars', 29),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('Victuailles en stock', 20, 'Victuailles en stock', 20),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Magazzini Alimentari Riuniti', 28, 'Magazzini Alimentari Riuniti', 28),
#  ('Cactus Comidas para llevar', 26, 'Cactus Comidas para llevar', 26),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Split Rail Beer & Ale', 21, 'Split Rail Beer & Ale', 21),
#  ('Trail-s Head Gourmet Provisioners', 33, 'Trail-s Head Gourmet Provisioners', 33),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Drachenblut Delikatessen', 24, 'Drachenblut Delikatessen', 24),
#  ('Blondel pre et fils', 19, 'Blondel pre et fils', 19),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Rancho grande', 13, 'Rancho grande', 13),
#  ('Island Trading', 14, 'Island Trading', 14),
#  ('Tradiao Hipermercados', 21, 'Tradiao Hipermercados', 21),
#  ('Sant Gourmet', 12, 'Sant Gourmet', 12),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Ottilies Kseladen', 17, 'Ottilies Kseladen', 17),
#  ('Tradiao Hipermercados', 21, 'Tradiao Hipermercados', 21),
#  ('Alfred-s Futterkiste', 20, 'Alfred-s Futterkiste', 20),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Tradiao Hipermercados', 21, 'Tradiao Hipermercados', 21),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('Tortuga Restaurante', 19, 'Tortuga Restaurante', 19),
#  ('Victuailles en stock', 20, 'Victuailles en stock', 20),
#  ('Piccolo und mehr', 16, 'Piccolo und mehr', 16),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Consolidated Holdings', 21, 'Consolidated Holdings', 21),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Victuailles en stock', 20, 'Victuailles en stock', 20),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Blauer See Delikatessen', 23, 'Blauer See Delikatessen', 23),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Old World Delicatessen', 22, 'Old World Delicatessen', 22),
#  ('Antonio Moreno Taquera', 22, 'Antonio Moreno Taquera', 22),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('La corne d-abondance', 20, 'La corne d-abondance', 20),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('France restauration', 19, 'France restauration', 19),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Lonesome Pine Restaurant', 24, 'Lonesome Pine Restaurant', 24),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('Seven Seas Imports', 18, 'Seven Seas Imports', 18),
#  ('Wolski Zajazd', 13, 'Wolski Zajazd', 13),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Godos Cocina Tpica', 18, 'Godos Cocina Tpica', 18),
#  ('Wilman Kala', 11, 'Wilman Kala', 11),
#  ('Godos Cocina Tpica', 18, 'Godos Cocina Tpica', 18),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Wilman Kala', 11, 'Wilman Kala', 11),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Cactus Comidas para llevar', 26, 'Cactus Comidas para llevar', 26),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Lonesome Pine Restaurant', 24, 'Lonesome Pine Restaurant', 24),
#  ('Let-s Stop N Shop', 17, 'Let-s Stop N Shop', 17),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('Galera del gastronmo', 20, 'Galera del gastronmo', 20),
#  ('Godos Cocina Tpica', 18, 'Godos Cocina Tpica', 18),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Du monde entier', 15, 'Du monde entier', 15),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('Maison Dewey', 12, 'Maison Dewey', 12),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Maison Dewey', 12, 'Maison Dewey', 12),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Ocano Atlntico Ltda.', 20, 'Ocano Atlntico Ltda.', 20),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Wellington Importadora', 22, 'Wellington Importadora', 22),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('Wellington Importadora', 22, 'Wellington Importadora', 22),
#  ('Wolski Zajazd', 13, 'Wolski Zajazd', 13),
#  ('Spcialits du monde', 18, 'Spcialits du monde', 18),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('Sant Gourmet', 12, 'Sant Gourmet', 12),
#  ('Wilman Kala', 11, 'Wilman Kala', 11),
#  ('Godos Cocina Tpica', 18, 'Godos Cocina Tpica', 18),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('Tortuga Restaurante', 19, 'Tortuga Restaurante', 19),
#  ('Rancho grande', 13, 'Rancho grande', 13),
#  ('Romero y tomillo', 16, 'Romero y tomillo', 16),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Berglunds snabbkp', 17, 'Berglunds snabbkp', 17),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('Ana Trujillo Emparedados y helados', 34, 'Ana Trujillo Emparedados y helados', 34),
#  ('La corne d-abondance', 20, 'La corne d-abondance', 20),
#  ('Galera del gastronmo', 20, 'Galera del gastronmo', 20),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('Richter Supermarkt', 18, 'Richter Supermarkt', 18),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Island Trading', 14, 'Island Trading', 14),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('Wellington Importadora', 22, 'Wellington Importadora', 22),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Cactus Comidas para llevar', 26, 'Cactus Comidas para llevar', 26),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Magazzini Alimentari Riuniti', 28, 'Magazzini Alimentari Riuniti', 28),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('B-s Beverages', 13, 'B-s Beverages', 13),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Morgenstern Gesundkost', 22, 'Morgenstern Gesundkost', 22),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('B-s Beverages', 13, 'B-s Beverages', 13),
#  ('Godos Cocina Tpica', 18, 'Godos Cocina Tpica', 18),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Magazzini Alimentari Riuniti', 28, 'Magazzini Alimentari Riuniti', 28),
#  ('Richter Supermarkt', 18, 'Richter Supermarkt', 18),
#  ('Alfred-s Futterkiste', 20, 'Alfred-s Futterkiste', 20),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Blauer See Delikatessen', 23, 'Blauer See Delikatessen', 23),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Ocano Atlntico Ltda.', 20, 'Ocano Atlntico Ltda.', 20),
#  ('Gourmet Lanchonetes', 19, 'Gourmet Lanchonetes', 19),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Furia Bacalhau e Frutos do Mar', 30, 'Furia Bacalhau e Frutos do Mar', 30),
#  ('Spcialits du monde', 18, 'Spcialits du monde', 18),
#  ('Old World Delicatessen', 22, 'Old World Delicatessen', 22),
#  ('Chop-suey Chinese', 17, 'Chop-suey Chinese', 17),
#  ('Toms Spezialitten', 17, 'Toms Spezialitten', 17),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Comrcio Mineiro', 15, 'Comrcio Mineiro', 15),
#  ('Blido Comidas preparadas', 24, 'Blido Comidas preparadas', 24),
#  ('France restauration', 19, 'France restauration', 19),
#  ('La corne d-abondance', 20, 'La corne d-abondance', 20),
#  ('La corne d-abondance', 20, 'La corne d-abondance', 20),
#  ('Split Rail Beer & Ale', 21, 'Split Rail Beer & Ale', 21),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Maison Dewey', 12, 'Maison Dewey', 12),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Ocano Atlntico Ltda.', 20, 'Ocano Atlntico Ltda.', 20),
#  ('Eastern Connection', 18, 'Eastern Connection', 18),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Que Delcia', 10, 'Que Delcia', 10),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('The Big Cheese', 14, 'The Big Cheese', 14),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Vaffeljernet', 12, 'Vaffeljernet', 12),
#  ('Pericles Comidas clsicas', 24, 'Pericles Comidas clsicas', 24),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Wolski Zajazd', 13, 'Wolski Zajazd', 13),
#  ('Ottilies Kseladen', 17, 'Ottilies Kseladen', 17),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('The Cracker Box', 15, 'The Cracker Box', 15),
#  ('Maison Dewey', 12, 'Maison Dewey', 12),
#  ('Wilman Kala', 11, 'Wilman Kala', 11),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Princesa Isabel Vinhos', 22, 'Princesa Isabel Vinhos', 22),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Godos Cocina Tpica', 18, 'Godos Cocina Tpica', 18),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('Alfred-s Futterkiste', 20, 'Alfred-s Futterkiste', 20),
#  ('Frankenversand', 14, 'Frankenversand', 14),
#  ('Romero y tomillo', 16, 'Romero y tomillo', 16),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Sant Gourmet', 12, 'Sant Gourmet', 12),
#  ('Around the Horn', 15, 'Around the Horn', 15),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Lonesome Pine Restaurant', 24, 'Lonesome Pine Restaurant', 24),
#  ('Rancho grande', 13, 'Rancho grande', 13),
#  ('Ottilies Kseladen', 17, 'Ottilies Kseladen', 17),
#  ('QUICK-Stop', 10, 'QUICK-Stop', 10),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('B-s Beverages', 13, 'B-s Beverages', 13),
#  ('Eastern Connection', 18, 'Eastern Connection', 18),
#  ('Wartian Herkku', 14, 'Wartian Herkku', 14),
#  ('Franchi S.p.A.', 14, 'Franchi S.p.A.', 14),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Kniglich Essen', 14, 'Kniglich Essen', 14),
#  ('Chop-suey Chinese', 17, 'Chop-suey Chinese', 17),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('Richter Supermarkt', 18, 'Richter Supermarkt', 18),
#  ('Old World Delicatessen', 22, 'Old World Delicatessen', 22),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('Drachenblut Delikatessen', 24, 'Drachenblut Delikatessen', 24),
#  ('Godos Cocina Tpica', 18, 'Godos Cocina Tpica', 18),
#  ('Suprmes dlices', 14, 'Suprmes dlices', 14),
#  ('LINO-Delicateses', 16, 'LINO-Delicateses', 16),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Chop-suey Chinese', 17, 'Chop-suey Chinese', 17),
#  ('Comrcio Mineiro', 15, 'Comrcio Mineiro', 15),
#  ('Spcialits du monde', 18, 'Spcialits du monde', 18),
#  ('Wolski Zajazd', 13, 'Wolski Zajazd', 13),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Die Wandernde Kuh', 17, 'Die Wandernde Kuh', 17),
#  ('Eastern Connection', 18, 'Eastern Connection', 18),
#  ('Bottom-Dollar Markets', 21, 'Bottom-Dollar Markets', 21),
#  ('Gourmet Lanchonetes', 19, 'Gourmet Lanchonetes', 19),
#  ('Folk och f HB', 13, 'Folk och f HB', 13),
#  ('La maison d-Asie', 16, 'La maison d-Asie', 16),
#  ('Hanari Carnes', 13, 'Hanari Carnes', 13),
#  ('Piccolo und mehr', 16, 'Piccolo und mehr', 16),
#  ('Cactus Comidas para llevar', 26, 'Cactus Comidas para llevar', 26),
#  ('HILARION-Abastos', 16, 'HILARION-Abastos', 16),
#  ('Eastern Connection', 18, 'Eastern Connection', 18),
#  ('North/South', 11, 'North/South', 11),
#  ('Blauer See Delikatessen', 23, 'Blauer See Delikatessen', 23),
#  ('Ricardo Adocicados', 18, 'Ricardo Adocicados', 18),
#  ('Franchi S.p.A.', 14, 'Franchi S.p.A.', 14),
#  ('Great Lakes Food Market', 23, 'Great Lakes Food Market', 23),
#  ('Reggiani Caseifici', 18, 'Reggiani Caseifici', 18),
#  ('Hungry Owl All-Night Grocers', 28, 'Hungry Owl All-Night Grocers', 28),
#  ('Save-a-lot Markets', 18, 'Save-a-lot Markets', 18),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('White Clover Markets', 20, 'White Clover Markets', 20),
#  ('Drachenblut Delikatessen', 24, 'Drachenblut Delikatessen', 24),
#  ('Queen Cozinha', 13, 'Queen Cozinha', 13),
#  ('Tortuga Restaurante', 19, 'Tortuga Restaurante', 19),
#  ('Lehmanns Marktstand', 19, 'Lehmanns Marktstand', 19),
#  ('LILA-Supermercado', 17, 'LILA-Supermercado', 17),
#  ('Ernst Handel', 12, 'Ernst Handel', 12),
#  ('Pericles Comidas clsicas', 24, 'Pericles Comidas clsicas', 24),
#  ('Simons bistro', 13, 'Simons bistro', 13),
#  ('Richter Supermarkt', 18, 'Richter Supermarkt', 18),
#  ('Bon app-', 8, 'Bon app-', 8),
#  ('Rattlesnake Canyon Grocery', 26, 'Rattlesnake Canyon Grocery', 26)]

# %% [markdown]
# ### 3. Replace string
#
# The `Customers` table contains null values in the `ContactTitle` column. Write a SQL command to replace these null values with the string 'N/A'.

# %%
# %%sql
#
# UPDATE
#     Customers
# SET
#     ContactTitle = COALESCE(ContactTitle, 'N/A');
# Out:
#  * sqlite:///Northwind.db
# 93 rows affected.
# []

# %% [markdown]
# ### 4. Extract characters
#
# Write a SQL command to extract the first three characters from the `City` column in the `Customers` table.

# %%
# %%sql
#
# SELECT
#     SUBSTRING(City, 1, 3) AS CitySubstring
# FROM
#     Customers;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Ber',),
#  ('Mxi',),
#  ('Mxi',),
#  ('Lon',),
#  ('Lul',),
#  ('Man',),
#  ('Str',),
#  ('Mad',),
#  ('Mar',),
#  ('Tsa',),
#  ('Lon',),
#  ('Bue',),
#  ('Mxi',),
#  ('Ber',),
#  ('Sao',),
#  ('Lon',),
#  ('Aac',),
#  ('Nan',),
#  ('Lon',),
#  ('Gra',),
#  ('Sao',),
#  ('Mad',),
#  ('Lil',),
#  ('Brc',),
#  ('Mnc',),
#  ('Nan',),
#  ('Tor',),
#  ('Lis',),
#  ('Bar',),
#  ('Sev',),
#  ('Cam',),
#  ('Eug',),
#  ('Car',),
#  ('Rio',),
#  ('San',),
#  ('Elg',),
#  ('Cor',),
#  ('Cow',),
#  ('Bra',),
#  ('Ver',),
#  ('Tou',),
#  ('Van',),
#  ('Wal',),
#  ('Fra',),
#  ('San',),
#  ('Bar',),
#  ('I. ',),
#  ('Por',),
#  ('Ber',),
#  ('Bru',),
#  ('Mon',),
#  ('Lei',),
#  ('Lon',),
#  ('Bue',),
#  ('Anc',),
#  ('Kln',),
#  ('Par',),
#  ('Mxi',),
#  ('Sal',),
#  ('Lis',),
#  ('Rio',),
#  ('Sao',),
#  ('Cun',),
#  ('Bue',),
#  ('Alb',),
#  ('Reg',),
#  ('Rio',),
#  ('Gen',),
#  ('Mad',),
#  ('Sta',),
#  ('Boi',),
#  ('Lon',),
#  ('Kob',),
#  ('Par',),
#  ('Lan',),
#  ('Cha',),
#  ('Por',),
#  ('But',),
#  ('Mns',),
#  ('Mxi',),
#  ('Sao',),
#  ('Kir',),
#  ('rhu',),
#  (None,),
#  (None,),
#  ('Lyo',),
#  ('Rei',),
#  ('Stu',),
#  ('Oul',),
#  ('Res',),
#  ('Sea',),
#  ('Hel',),
#  ('War',)]

# %% [markdown]
# ### 5. String concatenation
#
# Write a SQL query to concatenate the `FirstName` and `LastName` of employees in the `Employees` table into a new column `FullName`.

# %%
# %%sql
# SELECT
#     CONCAT(FirstName, " ", LastName) AS FullName
# FROM
#     employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy Davolio',),
#  ('Andrew Fuller',),
#  ('Janet Leverling',),
#  ('Margaret Peacock',),
#  ('Steven Buchanan',),
#  ('Michael Suyama',),
#  ('Robert King',),
#  ('Laura Callahan',),
#  ('Anne Dodsworth',)]

# %% [markdown]
# ### Challenge question
#
# You are working in the marketing department of your company and you have been given the task of conducting an email marketing campaign targeting all customers based in France.

# %% [markdown]
# You have a `Customers` table which includes an `Email` column. However, the data isn't perfect. Some email addresses might be duplicated, others might be `NULL`, and some might have unnecessary white spaces at the start or end of the address.
#
# Your task is to clean up the data and compile a list of unique email addresses to use for the marketing campaign. Here are the requirements:

# %% [markdown]
# 1. Exclude any `NULL` email addresses from your list. We can't send emails to addresses we don't have.
# 2. Make sure there are no duplicates in your list. We don't want to annoy our customers by sending them the same email multiple times.
# 3. Remove any unnecessary white spaces from the start or end of the email addresses. This will help avoid any errors when sending the emails.

# %% [markdown]
# Remember, the success of our campaign depends on the quality of this list!
#
# Your output should look something like this, though the exact email addresses will depend on the data in your `Customers` table:

# %% [raw]
# customer1@example.com
# customer2@example.com
# customer3@example.com

# %%
# %%sql
#
# SELECT
#     DISTINCT TRIM(Email)
# FROM
#     Customers
# WHERE
#     Country = 'France'
#     AND Email IS NOT NULL;
# Out:
#  * sqlite:///Northwind.db
# (sqlite3.OperationalError) no such column: Email
# [SQL: SELECT
#     DISTINCT TRIM(Email)
# FROM
#     Customers
# WHERE
#     Country = 'France'
#     AND Email IS NOT NULL;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Convert data type
#
# The `CAST` function is used to convert one data type to another. In this query, it is used to convert the `Salary` column from an integer to a string.

# %%
# %%sql
#
# SELECT
#     CAST(Salary AS CHAR) AS SalaryString
# FROM
#     Employees;

# %% [markdown]
# ### 2. Trim strings
#
# The `TRIM` function is used to remove leading and trailing spaces from a string. This query uses `TRIM` to remove spaces from the `ShipName` entries.

# %%
# %%sql
#
# SELECT
#     TRIM(ShipName) AS TrimmedShipName
# FROM
#     Orders;

# %% [markdown]
# ### 3. Replace string
#
# The `COALESCE` function returns the first non-null value in a list. In this case, it's used to replace `NULL` values in the `ContactTitle` column with `'N/A'`.

# %%
# %%sql
#
# UPDATE
#     Customers
# SET
#     ContactTitle = COALESCE(ContactTitle, 'N/A');

# %% [markdown]
# ### 4. Extract characters
#
# The `LEFT` function is used to extract a specified number of characters from a string, starting from the left. This query extracts the first three characters from the `City` column.

# %%
# %%sql
#
# SELECT
#     LEFT(City, 3) AS CitySubstring
# FROM
#     Customers;
# Out:
#  * sqlite:///Northwind.db
# (sqlite3.OperationalError) no such function: LEFT
# [SQL: SELECT
#     LEFT(City, 3) AS CitySubstring
# FROM
#     Customers;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### 5. String concatenation
#
# The `CONCAT` function is used to combine two or more strings into one. This query concatenates the `FirstName` and `LastName` columns with a space in between.

# %%
# %%sql
#
# SELECT
#     CONCAT(FirstName, ' ', LastName) AS FullName
# FROM
#     Employees;

# %% [markdown]
# ### Challenge question
#
# The SQL statement is reading data from the Customers table (`FROM` Customers).
#
# The `WHERE` clause filters out the customers who are based in France `(Country = 'France')` and whose email address is not `NULL (AND Email IS NOT NULL)`.
#
# The `SELECT DISTINCT TRIM(Email)` part of the statement is where the magic happens. `TRIM(Email)` removes any white spaces from the start and end of the email addresses. And `DISTINCT` ensures that each email address in your results is unique.
#
# Thus, this query will return a list of unique, cleaned-up email addresses for all customers in France, ready for you to use in your marketing campaign.

# %%
# %%sql
#
# SELECT
#     DISTINCT TRIM(Email)
# FROM
#     Customers
# WHERE
#     Country = 'France'
#     AND Email IS NOT NULL;
# Out:
#  * sqlite:///Northwind.db
# (sqlite3.OperationalError) no such column: Email
# [SQL: SELECT
#     DISTINCT TRIM(Email)
# FROM
#     Customers
# WHERE
#     Country = 'France'
#     AND Email IS NOT NULL;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# #
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
